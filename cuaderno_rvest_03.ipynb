# %% [markdown]
# <a href="https://colab.research.google.com/github/agusnieto77/Curso_R_IIDyPCA_2025/blob/main/cuaderno_rvest_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(rvest)
html_text2(html_elements(read_html("https://iidypca.conicet.gov.ar/categoria/noticias/page/1/"), "h1, h2, h3, h4, h5, h6, p")) |> writeLines("texto_iidypca.txt")

# %%
readLines("texto_iidypca.txt")
# Out:
#  [1] "ARCHIVO DE LA CATEGORÍA: Noticias"
#  [2] "Se presentó el libro Cuidados integrales en salud y prácticas comunitarias"
#  [3] "S presentó el libro Cuidados integrales en salud y prácticas comunitarias, compilado por Ana Domínguez Mon y Valeria Inés Puricelli, investigadoras del IIDYPCA (UNRN-CONICET)"
#  [4] "Al viento: lenguas de los territorios fuegopatagónicos y pampeanos en el Congreso de la Nación"
#  [5] "Exhibición de la muestra documental “Al viento. Lenguas de los territorios fuegopatagónicos y pampeanos” en el Congreso de la Nación."
#  [6] "IIDYPCA renueva su compromiso con la diversidad cultural y ecológica"
#  [7] "En el Día del Respeto a la Diversidad Cultural, desde IIDYPCA (UNRN CONICET) insistimos con la idea de el 12 de octubre que es una fecha para reconocernos y promover el respeto en diversidad."
#  [8] "“Vuelven”: un documental sobre el canto en resistencia de las mujeres del Abya Yala"
# ...
