# %% [markdown]
# <a href="https://colab.research.google.com/github/agusnieto77/Curso_R_IIDyPCA_2025/blob/main/cuaderno_rvest_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(rvest)

# %%
html <- read_html("https://www.lanacion.com.ar/")

# %%
print(html)
# Out:
# {html_document}
# <html lang="es">
# [1] <head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8 ...
# [2] <body class="ln">\n<noscript><iframe src="https://www.googletagmanager.co ...

# %%
body <- html_element(html, "body")

# %%
print(body)
# Out:
# {html_node}
# <body class="ln">
# [1] <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-GH ...
# [2] <div id="fusion-app">\n<div id="fusion-static-enter:1x1_dsk" style="displ ...
# [3] <script id="fusion-metadata" type="application/javascript">window.Fusion= ...
# [4] <script defer src="/pf/resources/js/LN/scriptAdblockDetector.min.js?d=191 ...
# [5] <script async="" src="https://btloader.com/tag?o=5698152924446720&amp;upa ...
# [6] <script type="application/javascript" src="/pf/resources/js/common/observ ...
# [7] <script id="fundingChoices" async="" defer type="text/javascript">\n      ...
# [8] <script id="script-video-home" src="/pf/resources/js/LN/scriptJwVideoHome ...
# [9] <script id="script-logo-event" defer type="text/javascript" src="/pf/reso ...

# %%
urls <- html_elements(body, "a") |> html_attr("href")

# %%
print(urls)
# Out:
#   [1] "/clima/"
#   [2] "https://club.lanacion.com.ar/"
#   [3] "https://lnmas.lanacion.com.ar/"
#   [4] "https://foodit.lanacion.com.ar/"
#   [5] "https://canchallena.lanacion.com.ar/"
#   [6] "https://bonvivir.com/"
#   [7] "https://masmusica.lanacion.com.ar/"
#   [8] "/"
#   [9] "https://www.lanacion.com.ar/dolar-hoy/"
#  [10] "https://www.lanacion.com.ar/tema/dolar-blue-tid67294/"
#  [11] "https://www.lanacion.com.ar/tema/dolar-tarjeta-tid50462/"
#  [12] "https://www.lanacion.com.ar/tema/dolar-mep/"
#  [13] "https://www.lanacion.com.ar/juegos/"
#  [14] "https://www.lanacion.com.ar/suscriptores/"
#  [15] "https://newsletter.lanacion.com.ar/?_ga=2.115587013.2111665650.1713785519-1414281100.1711030569"
#  [16] "https://www.lanacion.com.ar/"
#  [17] "#"
#  [18] "https://foodit.lanacion.com.ar/"
#  [19] "https://club.lanacion.com.ar/"
#  [20] "https://micuenta.lanacion.com.ar/"
#  [21] "https://masmusica.lanacion.com.ar/"
#  [22] "https://www.lanacion.com.ar/ultimas-noticias/"
# ...

# %%
titulos <- html_elements(body, "h1, h2, h3, h4, h5, h6")

# %%
print(titulos)
# Out:
# {xml_nodeset (166)}
#  [1] <h1 class="flex relative">\n<span class="visibility-hidden absolute">LA  ...
#  [2] <h4 class="text ln-text text-neutral-light-800 --prumo --font-black --fo ...
#  [3] <h1 class="text ln-text title --prumo --font-medium --font-4xl">\n<span  ...
#  [4] <h2 class="text ln-text subhead --font-s">Casanello ordenó que Pablo Atc ...
#  [5] <h2 class="text ln-text title --prumo --font-medium --font-m-l">\n<span  ...
#  [6] <h2 class="text ln-text title --prumo --font-medium --font-m-l">\n<span  ...
#  [7] <h2 class="text ln-text title --prumo --font-medium --font-m-l">\n<span  ...
#  [8] <h2 class="text ln-text title --prumo --font-medium --font-m-l">\n<span  ...
#  [9] <h2 class="text ln-text title --prumo --font-medium --font-m-l">\n<span  ...
# [10] <h2 class="text ln-text title --prumo --font-medium --font-m-l">\n<span  ...
# [11] <h2 class="text ln-text title --prumo --font-medium --font-m-l">\n<span  ...
# ...

# %%
titulos_txt <- titulos |> html_text2()

# %%
titulos_txt |> print()
# Out:
#   [1] "LA NACION"
#   [2] "Medidas de Milei"
#   [3] "Avanza el caso Spagnuolo. Tres días de indagatorias clave y un empresario preso en Mendoza que se negó a declarar"
#   [4] "Casanello ordenó que Pablo Atchabahian cumpla prisión domiciliaria después de que eludió a la Justicia durante semanas; el miércoles tiene que presentarse Spagnuolo; esta semana están citados también Garbellini y Calvete"
#   [5] "El futuro de la Corte. El nombre de Fernández Sagasti divide aguas en el peronismo, que redefine su mapa de poder en el Senado"
#   [6] "Mercados. El dólar cayó y tocó el valor más bajo en un mes, en pleno boom de emisión de deuda empresarial"
#   [7] "El antes y después de la explosión. Estas son las fábricas alcanzadas por el fuego en el polígono industrial de Ezeiza"
#   [8] "\"Trump vuelve a ganar a lo grande\". El artículo que destacó la Casa Blanca sobre los beneficios de la ayuda a la Argentina"
# ...

# %%
parrafos <- html_elements(body, "p")

# %%
print(parrafos)
# Out:
# {xml_nodeset (12)}
#  [1] <p class="text ln-text --editoriales-roof --prumo --font-s">EDITORIALES</p>
#  [2] <p class="text ln-text sm-none --font-bold --font-xs">Secciones</p>\n
#  [3] <p class="text ln-text sm-none --font-bold --font-xs">Revistas</p>\n
#  [4] <p class="text ln-text sm-none --font-bold --font-xs">Redes sociales:</p>\n
#  [5] <p class="text ln-text sm-none --font-bold --font-xs">Descargá la app:</ ...
#  [6] <p class="text ln-text flex flex-column gap-9 --font-xs"><span><b class= ...
#  [7] <p class="text ln-text flex flex-column gap-9 --font-xs"><span><b class= ...
#  [8] <p class="text ln-text --font-xs"><span><b class="--font-bold">Propietar ...
#  [9] <p class="text ln-text --font-xs"><span><b class="--font-bold">Oficinas: ...
# [10] <p class="text ln-text --font-xs">© Copyright <!-- -->2025<!-- --> SA LA ...
# [11] <p class="text ln-text flex flex-column gap-4 flex-row_m --font-xs"><b c ...
# ...

# %%
parrafos_txt <- parrafos |> html_text2()

# %%
for(p in parrafos_txt) { cat(p, "\n") }
# Out:
# EDITORIALES
# Secciones
# Revistas
# Redes sociales:
# Descargá la app:
# Director: Fernán Saguier.ISSN (lanacion.com.ar) 2469-0597
# Fecha de Edición: 17/11/2025Número de Edición: 10933
# Propietario: S.A. LA NACION - Zepita 3251,Cda. de Bs. As. C1285ABG | Tel. 54 11 5500-1800
# Oficinas: Av. del Libertador 101, Vte. López,Prov. de Bs. As. Arg. - B1638BEA | Tel. 54 11 6090-5000
# © Copyright 2025 SA LA NACION | Todos los derechos reservados. Dirección Nacional del Derecho de Autor DNDA - EXPEDIENTE DNDA (renovación) RL-2023-95334553-APN-DNDA#MJ.
# Queda prohibida la reproducción total o parcial del presente diario.
# Protegido por reCAPTCHA: CondicionesPrivacidad
# Miembro de GDA. Grupo de Diarios América
