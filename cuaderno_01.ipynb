# %% [markdown]
# <a href="https://colab.research.google.com/github/agusnieto77/Curso_R_IIDyPCA_2025/blob/main/cuaderno_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(rvest)

# %%
html <- read_html("https://www.lanacion.com.ar/")

# %%
getwd()
# Out:
# [1] "/content"
